# %% [markdown]
# # Amazon Recommendation System - Lab
#
# ## Introduction
#
# Now that you've gotten an introduction to collaborative filtering and recommendation systems, it's time to put your skills to test and build a recommendation system for a real world dataset! For this lab, you'll be using a dataset regarding the book reviews on the Amazon marketplace. While the previous lesson focused on user-based recommendation systems, you'll apply a parallel process for an item-based recommendation system to recommend similar books at the bottom of the product page.
#
# ## Objectives
#
# In this lab you will:
#
# - Use graph-based similarity metrics to create a collaborative filtering recommender system

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

G = nx.Graph()

df = pd.read_csv('books_data.edgelist', names=['source', 'target', 'weight'], delimiter=' ')
df.head()
# Out:
#        source      target  weight
# 0  0827229534  0804215715     0.7
# 1  0827229534  156101074X     0.5
# 2  0827229534  0687023955     0.8
# 3  0827229534  0687074231     0.8
# 4  0827229534  082721619X     0.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741124 entries, 0 to 741123
# Data columns (total 3 columns):
# source    741124 non-null object
# target    741124 non-null object
# weight    741124 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 17.0+ MB

# %% [markdown]
# ## Load the Metadata
#
# Import the metadata available in the file `'books_meta.txt'` (note it is `'\t'` seperated).

# %%
# Your code here
meta_df = pd.read_csv("books_meta.txt", delimiter='\t')
meta_df.head()
# Out:
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  SalesRank  \
# 0  clergi sermon subject religion preach spiritu ...  Book     396585
# 1  subject witchcraft earth religion spiritu base...  Book     168596
# 2       general hobbi subject craft home garden book  Book    1270652
# 3  spiritu translat commentari christian book gui...  Book     631289
# 4  subject religion spiritu busi christian live w...  Book     455160
#
#    TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 0             2        5.0                 8             0.80
# 1            12        4.5                 9             0.85
# 2             1        5.0                 0             0.00
# 3             1        4.0                 6             0.79
# 4             0        0.0                 4             1.00

# %% [markdown]
# ## Select Books to Test Your Recommender On
#
# Select a small subset of books that you are interested in generating recommendations for.

# %%
# Your code here
books_to_test = meta_df.loc[:20, 'Title']

# %% [markdown]
# ## Generate Recommendations for a Few Books of Choice
#
# The `'books_data.edgelist'` has conveniently already calculated the distance between items for you. Given this preprocessed data, it's time to employ collaborative filtering to generate recommendations! Generate the top 10 recommendations for each book in the subset you chose. Be sure to print the book name that you are generating recommendations for as well as the name of the books being recommended.

# %%
def get_recs(title, num_of_recs):
    
    # get book number
    book_num = meta_df[meta_df.Title == title].ASIN.values[0]
    
    # find all edges with the book number as a source or target
    edges = df[(df.source == book_num) | (df.target == book_num)]
    
    # sort by weights and slice by num_of_recs
    edges = edges.sort_values('weight', ascending=False)[:num_of_recs]
    
    # get recomended book numbers
    rec_book_nums = []
    for row in edges.index:
        if edges.source[row] == book_num:
            rec_book_nums.append(edges.target[row])
        else:
            rec_book_nums.append(edges.source[row])
    
    # translate rec_book_nums to titles
    rec_book_titles = [meta_df[meta_df.ASIN == num].Title.values[0] for num in rec_book_nums]
    
    # print results
    print('Recomendations for {}'.format(title))
    if rec_book_titles == []:
        print('ZERO RECOMENDATIONS')
    for n, book in enumerate(rec_book_titles):
        print("{}) {}".format(n+1, book))

# %%
for book in books_to_test:
    get_recs(book, 10)
    print('\n\n')
# Out:
# Recomendations for Patterns of Preaching: A Sermon Sampler
# 1) The Four Pages of the Sermon: A Guide to Biblical Preaching
# 2) Performing the Word: Preaching As Theatre
# 3) Witness of Preaching
# 4) Interpreting the Gospel: An Introduction to Preaching
# 5) Handbook of Contemporary Preaching
# 6) Just Say the Word!: Writing for the Ear
# 7) Preaching Liberation (Fortress Resources for Preaching)
# 8) The Preaching Life
#
#
#
# Recomendations for Candlemas: Feast of Flames
# 1) Lammas
# 2) Ostara: Customs, Spells & Rituals for the Rites of Spring
# 3) The Pagan Book of Halloween : A Complete Guide to the Magick, Incantations, Recipes, Spells, and Lore
# 4) Beltane: Springtime Rituals, Lore and Celebration
# 5) Midsummer: Magical Celebrations of the Summer Solstice
# 6) Halloween: Customs, Recipes & Spells
# 7) Yule: A Celebration of Light and Warmth
# 8) The Summer Solstice : Celebrating the Journey of the Sun from May Day to Harvest
# 9) The Winter Solstice: The Sacred Traditions of Christmas
#
#
#
# Recomendations for World War II Allied Fighter Planes Trading Cards
# ZERO RECOMENDATIONS
#
#
#
# Recomendations for Life Application Bible Commentary: 1 and 2 Timothy and Titus
# 1) Ephesians (Life Application Bible Commentary)
# 2) 1 Peter 2 Peter Jude (Life Application Bible Commentary)
# 3) Acts (Life Application Bible Commentary)
# 4) 1, 2, & 3 John (Life Application Bible Commentary)
# 5) 1 & 2 Thessalonians (Life Application Bible Commentary)
# 6) Life Application Bible Commentary: Philippians Colossians and Philemon (Life Application Bible Commentary)
#
#
#
# Recomendations for Prayers That Avail Much for Business: Executive
# 1) Prayers That Avail Much: Three Bestselling Works Complete In One Volume, 25th Anniversary Commemorative
# 2) Prayers That Avail Much for Men
# 3) Prayers That Avail Much for the Workplace: The Business Handbook of Scriptural Prayer
# 4) Prayers That Avail Much for Kids: Short and Simple Prayers Packed With the Power of God's Word
#
#
#
# Recomendations for How the Other Half Lives: Studies Among the Tenements of New York
# 1) The Battle with the Slum
# 2) Old New York in Early Photographs
# 3) Jacob Riis (55)
# 4) Five Points: The 19th Century New York City Neighborhood That Invented Tap Dance, Stole Elections, and Became the World's Most Notorious Slum
#
#
#
# Recomendations for Losing Matt Shepard
# 1) The Laramie Project (Vintage Originals)
# 2) From Hate Crimes to Human Rights: A Tribute to Matthew Shepard
# 3) Taliban: Militant Islam, Oil and Fundamentalism in Central Asia
# 4) The Hidden Injuries of Class
# 5) We'll Call You If We Need You: Experiences of Women Working Construction
# 6) Laramie Project
#
#
#
# Recomendations for Making Bread: The Taste of Traditional Home-Baking
# ZERO RECOMENDATIONS
#
#
#
# Recomendations for The Edward Said Reader
# 1) Orientalism (Vintage)
# 2) Culture and Imperialism (Vintage)
# 3) Culture and Resistance : Conversations with Edward W. Said
# 4) Power, Politics, and Culture
# 5) Out of Place : A Memoir
#
#
#
# Recomendations for Resetting the Clock : Five Anti-Aging Hormones That Improve and Extend Life
# 1) Bypassing Bypass Surgery: Chelation Therapy: A Non-Surgical Treatment for Reversing Arteriosclersis, Improving Blocked Circulation, and Slowing the Aging Process
# 2) Grow Young with HGH: The Amazing Medically Proven Plan to Reverse Aging
# 3) Maximize Your Vitality & Potency: For Men Over 40
# 4) Stopping the Clock : Dramatic Breakthroughs in Anti-Aging and Age Reversal Techniques
#
#
#
# Recomendations for Fantastic Food with Splenda : 160 Great Recipes for Meals Low in Sugar, Carbohydrates, Fat, and Calories
# 1) Unbelievable Desserts With Splenda: Sweet Treats Low in Sugar, Fat and Calories
#
#
#
# Recomendations for Clockwork Worlds : Mechanized Environments in SF (Contributions to the Study of Science Fiction and Fantasy)
# ZERO RECOMENDATIONS
#
#
#
# Recomendations for Wake Up and Smell the Coffee
# 1) Pounding Nails in the Floor With My Forehead
# 2) Sex, Drugs, Rock & Roll
# 3) The Essential Bogosian: Talk Radio, Drinking in America, Funhouse & Men Inside
# 4) Suburbia
# 5) Notes from Underground
# 6) Mall
#
#
#
# Recomendations for War at Sea: A Naval History of World War II
# 1) How They Won the War in the Pacific: Nimitz and His Admirals
# 2) Touched With Fire: The Land War in the South Pacific
# 3) Midway: The Battle that Doomed Japan, the Japanese Navy's Story
#
#
#
# Recomendations for Telecommunications Cost Management
# 1) Telecommunication Expense Management: How to Audit Your Bills, Reduce Expenses and Negotiate Favorable Rates
# 2) Telecommunications Cost Management (Artech House Telecommunications Library)
#
#
#
# Recomendations for Ultimate Marvel Team-Up
# 1) The Ultimates Vol. 2: Homeland Security
#
#
#
# Recomendations for Computed Tomography : Fundamentals, System Technology, Image Quality, Applications
# 1) CT Teaching Manual
# 2) Computed Tomography
# 3) Spiral CT: Principles, Techniques and Applications
# 4) Registry Review in Computed Tomography
# 5) Computed Tomography: Physical Principles, Clinical Applications, and Quality Control
# 6) Computed Tomography: Principles, Design, Artifacts, and Recent Advances (SPIE PRESS Monograph Vol. PM114) (Spie Press Monograph . Pm114)
# 7) Principles of Computerized Tomographic Imaging (Classics in Applied Mathematics, 33)
# 8) The Mathematics of Computerized Tomography (Classics in Applied Mathematics, 32)
#
#
#
# Recomendations for Strange Fire: A Novel
# ZERO RECOMENDATIONS
#
#
#
# Recomendations for The Casebook of Sherlock Holmes, Volume 2 (Casebook of Sherlock Holmes)
# ZERO RECOMENDATIONS
#
#
#
# Recomendations for Jailed for Freedom: American Women Win the Vote
# 1) One Woman One Vote: Rediscovering the Woman Suffrage Movement
# 2) From Equal Suffrage to Equal Rights: Alice Paul and the National Woman's Party, 1910-1928 (American Social Experience (Paperback))
# 3) Century of Struggle: The Woman's Rights Movement in the United States
#
#
#
# Recomendations for Chicken Little
# 1) The Gingerbread Man
# 2) Henny-penny
# 3) Chicken Little (Growing Tree)
# 4) Chicken Little
# 5) Chicken Little
# 6) Henny Penny
# 7) The Little Red Hen

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you effectively created a recommendation system for a real world dataset!
